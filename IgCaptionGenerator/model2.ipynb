# %% [markdown]
# # First model outline

# %%
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.inception_v3 import InceptionV3, preprocess_input
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.layers import Input, Embedding, LSTM, Dense, Dropout, Add
from tensorflow.keras.models import Model
from tensorflow.keras.preprocessing.image import load_img
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import RepeatVector

from sklearn.model_selection import train_test_split
import numpy as np
import matplotlib.pyplot as plt
import spacy
import pandas as pd
import zipfile
import nltk
import re
import json
import zipfile
import os
import io

# %%
zip_file_path = 'C:/Users/Admin/Desktop/instagram_data.zip'
img_folder = 'img'
csv_file_name = 'captions_csv.csv'

# %% [markdown]
# ## Filtering and captions preprocessing

# %%
bad_words = ['fuck', 'bitch', 'hoe', 'motherfucker']

with zipfile.ZipFile(zip_file_path, 'r') as z:
    with z.open(csv_file_name) as f:
        df = pd.read_csv(f)

def tokenize_caption(text):
    text = text.lower()
    text = re.sub(r' +|\t', ' ', text)
    tokens = nltk.word_tokenize(text)
    tokens = ['<start>'] + tokens + ['<end>']
    return tokens

df = df.dropna(subset=['Caption']) 
df = df[['Image File', 'Caption']]
df = df.drop_duplicates(subset=['Caption'])
df = df[df['Caption'].apply(len) < 60]
df = df[~df['Caption'].str.contains(r'http\S+|www\S+', regex=True)]
df = df[~df['Caption'].str.contains('|'.join(bad_words), case=False)]
df['Tokenized Caption'] = df['Caption'].apply(tokenize_caption)

# %% [markdown]
# ## Tokenization

# %%
'''
data = pd.read_csv('caption_data.csv')

special_tokens = ['<start>', '<end>']

tokenized_captions = data['Tokenized Caption'].tolist()

tokenizer = Tokenizer(filters='.,', oov_token='<unk>')

tokenizer.fit_on_texts(special_tokens)
tokenizer.fit_on_texts(tokenized_captions)
encoded_tokens = tokenizer.texts_to_sequences(tokenized_captions)

data['Encoded Tokens'] = encoded_tokens

data.to_csv('caption_data.csv', sep=',', index=False, encoding='utf-8')

'''
special_tokens = ['<start>', '<end>']

tokenized_captions = df['Tokenized Caption'].tolist()

tokenizer = Tokenizer(filters='.,', oov_token='<unk>')

tokenizer.fit_on_texts(special_tokens + tokenized_captions)

encoded_tokens = tokenizer.texts_to_sequences(tokenized_captions)

df['Encoded Tokens'] = encoded_tokens

# %% [markdown]
# ## Image features extraction

# %%
model_incep = InceptionV3(include_top=False, weights='imagenet')
image_feature_extractor = Model(model_incep.input, model_incep.layers[-1].output)

def extract_image_features(image_path):
    img = load_img(image_path, target_size=(299, 299))

    img_array = image.img_to_array(img)

    img_array = np.expand_dims(img_array, axis=0)

    img_array = preprocess_input(img_array)

    features = image_feature_extractor.predict(img_array)

    return features

'''
with zipfile.ZipFile(zip_file_path, 'r') as z:
    for file in z.namelist():
        if file.startswith(img_folder):
            img_name = os.path.basename(file)
            if img_name in images_names[:20]:
                print(file)
        
'''

images_names = df['Image File'].values
images_names = [os.path.basename(img) + '.jpg' for img in images_names]

image_features = {}
with zipfile.ZipFile(zip_file_path, 'r') as z:
    for file in z.namelist():
        if file.startswith(img_folder):
            img_name = os.path.basename(file)
            if img_name in images_names[:2000]:
                print(f"Processing {file}")
                with z.open(file) as f:
                    image_data = io.BytesIO(f.read())
                    features = extract_image_features(image_data) 
                    image_features[img_name] = features.flatten()
# Out:
# Processing img/insta10.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step
# Processing img/insta902.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step
# Processing img/insta903.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step
# Processing img/insta907.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step
# Processing img/insta908.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step
# Processing img/insta910.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step
# Processing img/insta911.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step
# Processing img/insta916.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step
# Processing img/insta917.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step
# Processing img/insta918.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step
# Processing img/insta919.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step
# Processing img/insta92.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step
# Processing img/insta920.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step
# Processing img/insta922.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step
# Processing img/insta923.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step
# Processing img/insta926.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step
# Processing img/insta927.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step
# Processing img/insta928.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step
# Processing img/insta931.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step
# Processing img/insta932.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step
# Processing img/insta933.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step
# Processing img/insta935.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step
# Processing img/insta937.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step
# Processing img/insta941.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step
# Processing img/insta942.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step
# Processing img/insta943.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step
# Processing img/insta946.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step
# Processing img/insta949.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step
# Processing img/insta950.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step
# Processing img/insta951.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step
# Processing img/insta954.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step
# Processing img/insta955.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step
# Processing img/insta956.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step
# Processing img/insta957.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step
# Processing img/insta958.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step
# Processing img/insta959.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step
# Processing img/insta962.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step
# Processing img/insta968.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step
# Processing img/insta969.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step
# Processing img/insta974.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step
# Processing img/insta976.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step
# Processing img/insta98.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step
# Processing img/insta980.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step
# Processing img/insta982.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step
# Processing img/insta984.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step
# Processing img/insta987.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step
# Processing img/insta988.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step
# Processing img/insta994.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step
# Processing img/insta995.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step
# Processing img/insta996.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step
# Processing img/insta997.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step
# Processing img/insta998.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step
# Processing img/insta999.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step

# %% [markdown]
# ## Training data

# %%
df['Image File'] = df['Image File'].apply(lambda x: os.path.basename(x) + '.jpg')

df['Image Features'] = df['Image File'].map(image_features.get)
df = df.dropna(subset = ['Image Features'])

max_caption_len = max(len(caption) for caption in df['Encoded Tokens'])
captions = pad_sequences(df['Encoded Tokens'], maxlen = max_caption_len, padding='post')

image_features_array = np.array(df['Image Features'].tolist())

X1_train, X1_val, X2_train, X2_val, y_train, y_val = train_test_split(
    image_features_array, captions[:, :-1], captions[:, 1:], test_size = 0.2, random_state = 42
)

vocab_size = len(tokenizer.word_index) + 1

y_train_cat = to_categorical(y_train, num_classes = vocab_size)
y_val_cat = to_categorical(y_val, num_classes = vocab_size)

y_train_cat = y_train_cat.reshape(y_train.shape[0], y_train.shape[1], vocab_size)
y_val_cat = y_val_cat.reshape(y_val.shape[0], y_val.shape[1], vocab_size)

# %% [markdown]
# ## Model

# %%
def build_model(max_caption_len, vocab_size, image_features_array, learning_rate):
    input_image = Input(shape=(image_features_array.shape[1],))
    cnn_layer1 = Dropout(0.4)(input_image)
    cnn_layer2 = Dense(256, activation = 'relu')(cnn_layer1)

    input_text = Input(shape=(max_caption_len -1,))
    lstm_layer1 = Embedding(vocab_size, 256, mask_zero = True)(input_text)
    lstm_layer2 = Dropout(0.4)(lstm_layer1)
    lstm_layer3 = LSTM(256, activation = 'tanh', return_sequences = True)(lstm_layer2)

    merging_layer = Add()([
        RepeatVector(max_caption_len - 1)(cnn_layer2), 
        lstm_layer3
    ]) 
    final_dense = Dense(256, activation = 'relu')(merging_layer)
    output = Dense(vocab_size, activation = 'softmax')(final_dense)

    model = Model(inputs = [input_image, input_text], outputs = output)

    optimizer = Adam(learning_rate = learning_rate)
    model.compile(loss = 'categorical_crossentropy', optimizer = optimizer, metrics = ['accuracy'])

    return model


max_caption_len = max_caption_len
vocab_size = len(tokenizer.word_index) + 1

captioning_model = build_model(max_caption_len, vocab_size, image_features_array, 0.001)

captioning_model.summary()
# Out:
# Model: "functional_43"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_59      │ (None, 131072)    │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ input_layer_60      │ (None, 20)        │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_20          │ (None, 131072)    │          0 │ input_layer_59[0… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ embedding_10        │ (None, 20, 256)   │  2,138,880 │ input_layer_60[0… │
# │ (Embedding)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_22 (Dense)    │ (None, 256)       │ 33,554,688 │ dropout_20[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_21          │ (None, 20, 256)   │          0 │ embedding_10[0][… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ not_equal_10        │ (None, 20)        │          0 │ input_layer_60[0… │
# │ (NotEqual)          │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ repeat_vector_3     │ (None, 20, 256)   │          0 │ dense_22[0][0]    │
# │ (RepeatVector)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm_10 (LSTM)      │ (None, 20, 256)   │    525,312 │ dropout_21[0][0], │
# │                     │                   │            │ not_equal_10[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_8 (Add)         │ (None, 20, 256)   │          0 │ repeat_vector_3[… │
# │                     │                   │            │ lstm_10[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_23 (Dense)    │ (None, 20, 256)   │     65,792 │ add_8[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_24 (Dense)    │ (None, 20, 8355)  │  2,147,235 │ dense_23[0][0]    │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 38,431,907 (146.61 MB)
#  Trainable params: 38,431,907 (146.61 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## Training

# %%
epochs = 50
batch_size = 32

history = captioning_model.fit(
    [X1_train, X2_train], 
    y_train_cat,
    validation_data = ([X1_val, X2_val], y_val_cat),
    epochs = epochs,
    batch_size = batch_size,
    verbose = 1
)
# Out:
# Epoch 1/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 78s 894ms/step - accuracy: 0.5682 - loss: 6.2029 - val_accuracy: 0.6994 - val_loss: 2.3214
# Epoch 2/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 31s 617ms/step - accuracy: 0.7239 - loss: 1.9408 - val_accuracy: 0.7494 - val_loss: 2.0451
# Epoch 3/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 31s 606ms/step - accuracy: 0.7405 - loss: 1.7893 - val_accuracy: 0.7492 - val_loss: 2.0299
# Epoch 4/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 30s 596ms/step - accuracy: 0.7539 - loss: 1.6022 - val_accuracy: 0.7494 - val_loss: 2.1126
# Epoch 5/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 30s 595ms/step - accuracy: 0.7575 - loss: 1.4618 - val_accuracy: 0.7501 - val_loss: 2.1599
# Epoch 6/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 31s 611ms/step - accuracy: 0.7609 - loss: 1.3084 - val_accuracy: 0.7498 - val_loss: 2.3507
# Epoch 7/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 30s 601ms/step - accuracy: 0.7612 - loss: 1.1705 - val_accuracy: 0.7467 - val_loss: 2.4738
# Epoch 8/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 29s 582ms/step - accuracy: 0.7801 - loss: 1.0236 - val_accuracy: 0.7430 - val_loss: 2.5528
# Epoch 9/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 31s 611ms/step - accuracy: 0.7992 - loss: 0.9033 - val_accuracy: 0.7420 - val_loss: 2.7964
# Epoch 10/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 30s 602ms/step - accuracy: 0.8095 - loss: 0.8310 - val_accuracy: 0.7362 - val_loss: 2.8012
# Epoch 11/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 30s 595ms/step - accuracy: 0.8095 - loss: 0.8275 - val_accuracy: 0.7406 - val_loss: 2.8628
# Epoch 12/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 30s 597ms/step - accuracy: 0.8164 - loss: 0.7790 - val_accuracy: 0.7396 - val_loss: 2.9424
# Epoch 13/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━
50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 31s 626ms/step - accuracy: 0.9515 - loss: 0.1721 - val_accuracy: 0.7333 - val_loss: 4.4194
# Epoch 37/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 30s 601ms/step - accuracy: 0.9587 - loss: 0.1378 - val_accuracy: 0.7300 - val_loss: 4.3414
# Epoch 38/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 30s 597ms/step - accuracy: 0.9593 - loss: 0.1360 - val_accuracy: 0.7326 - val_loss: 4.6049
# Epoch 39/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 30s 603ms/step - accuracy: 0.9637 - loss: 0.1250 - val_accuracy: 0.7334 - val_loss: 4.5255
# Epoch 40/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 30s 592ms/step - accuracy: 0.9652 - loss: 0.1180 - val_accuracy: 0.7318 - val_loss: 4.5260
# Epoch 41/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 29s 578ms/step - accuracy: 0.9678 - loss: 0.1140 - val_accuracy: 0.7324 - val_loss: 4.5279
# Epoch 42/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 30s 590ms/step - accuracy: 0.9649 - loss: 0.1312 - val_accuracy: 0.7336 - val_loss: 4.7132
# Epoch 43/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 30s 596ms/step - accuracy: 0.9647 - loss: 0.1223 - val_accuracy: 0.7315 - val_loss: 4.6760
# Epoch 44/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 30s 597ms/step - accuracy: 0.9665 - loss: 0.1172 - val_accuracy: 0.7326 - val_loss: 4.7293
# Epoch 45/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 30s 594ms/step - accuracy: 0.9675 - loss: 0.1130 - val_accuracy: 0.7316 - val_loss: 4.7743
# Epoch 46/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 30s 595ms/step - accuracy: 0.9732 - loss: 0.0947 - val_accuracy: 0.7311 - val_loss: 4.8363
# Epoch 47/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 30s 597ms/step - accuracy: 0.9766 - loss: 0.0810 - val_accuracy: 0.7329 - val_loss: 4.8647
# Epoch 48/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 30s 600ms/step - accuracy: 0.9730 - loss: 0.0933 - val_accuracy: 0.7294 - val_loss: 4.8931
# Epoch 49/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 30s 600ms/step - accuracy: 0.9748 - loss: 0.0893 - val_accuracy: 0.7312 - val_loss: 4.8589
# Epoch 50/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 30s 604ms/step - accuracy: 0.9766 - loss: 0.0840 - val_accuracy: 0.7303 - val_loss: 4.9484

# %% [markdown]
# ## Generating captions

# %%
def generate_caption(image_feature, max_len = max_caption_len):
    input_seq = np.zeros((1, max_len - 1), dtype = np.int32)
    input_seq[0, 0] = tokenizer.word_index['<start>']
    
    captions = []
    for i in range(1, max_len-1): 

        pred = captioning_model.predict([
            np.array([image_feature]), 
            input_seq
        ])
        
        pred_word_index = np.argmax(pred[0, i-1, :])
        
        pred_word = tokenizer.index_word.get(pred_word_index, '')
        
        if pred_word and pred_word != '<unk>':
            captions.append(pred_word)
        
        input_seq[0, i] = pred_word_index
        
        if pred_word == '<end>':
            break
    
    return ' '.join(captions)


sample_image_feature = image_features_array[299]

generated_caption = generate_caption(sample_image_feature)

print("\nWygenerowany podpis:", generated_caption)

original_tokens = df['Tokenized Caption'].iloc[299]
original_caption = ' '.join(original_tokens)

print("\nOryginalny podpis:", original_caption)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 def generate_caption(image_feature, max_len = max_caption_len):
#       2     input_seq = np.zeros((1, max_len - 1), dtype = np.int32)
#       3     input_seq[0, 0] = tokenizer.word_index['<start>']
#
# NameError: name 'max_caption_len' is not defined
